# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
df = pd.read_csv("diet.csv",index_col=0)
df2 = pd.read_csv('iris.csv')
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
cluster = list(df2['species'])
df2['cluster'] = pd.Series(cluster)

df2['cluster'].index
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#        cluster
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
df2 = shuffle(df2)
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 69            5.6          2.5           3.9          1.1  versicolor
# 146           6.3          2.5           5.0          1.9   virginica
# 47            4.6          3.2           1.4          0.2      setosa
# 137           6.4          3.1           5.5          1.8   virginica
# 73            6.1          2.8           4.7          1.2  versicolor
# ..            ...          ...           ...          ...         ...
# 131           7.9          3.8           6.4          2.0   virginica
# 80            5.5          2.4           3.8          1.1  versicolor
# 8             4.4          2.9           1.4          0.2      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 67            5.8          2.7           4.1          1.0  versicolor
#
#         cluster
# 69   versicolor
# 146   virginica
# 47       setosa
# 137   virginica
# 73   versicolor
# ..          ...
# ...

# %%
cluster = list(df2['species'])
print(cluster)
df2['cluster'] = pd.Series(cluster)
df2
# Out:
# ['versicolor', 'virginica', 'setosa', 'virginica', 'versicolor', 'versicolor', 'setosa', 'versicolor', 'versicolor', 'virginica', 'virginica', 'virginica', 'setosa', 'setosa', 'versicolor', 'virginica', 'setosa', 'setosa', 'setosa', 'virginica', 'versicolor', 'setosa', 'virginica', 'virginica', 'setosa', 'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa', 'virginica', 'setosa', 'versicolor', 'virginica', 'versicolor', 'setosa', 'versicolor', 'virginica', 'setosa', 'virginica', 'setosa', 'virginica', 'versicolor', 'virginica', 'setosa', 'versicolor', 'virginica', 'versicolor', 'setosa', 'versicolor', 'virginica', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa', 'setosa', 'virginica', 'setosa', 'versicolor', 'versicolor', 'virginica', 'versicolor', 'versicolor', 'virginica', 'virginica', 'virginica', 'virginica', 'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor', 'virginica', 'virginica', 'versico
# ...

# %%
df2['cluster'][0:50]
# Out:
# 69      virginica
# 146    versicolor
# 47     versicolor
# 137     virginica
# 73     versicolor
# 95         setosa
# 32     versicolor
# 61      virginica
# 98         setosa
# 107    versicolor
# 133        setosa
# 144     virginica
# 35         setosa
# 21         setosa
# 88     versicolor
# 130     virginica
# 17         setosa
# 3       virginica
# 4      versicolor
# 100     virginica
# 77         setosa
# 36     versicolor
# 125    versicolor
# 105    versicolor
# 34     versicolor
# 70      virginica
# 26         setosa
# 54         setosa
# 56         setosa
# 0      versicolor
# 117    versicolor
# 19      virginica
# 58         setosa
# 132    versicolor
# 81     versicolor
# 15      virginica
# 71      virginica
# 112    versicolor
# 12         setosa
# 121        setosa
# 23      virginica
# 139        setosa
# 52         setosa
# 104    versicolor
# 44         setosa
# 99     versicolor
# 108        setosa
# 53     versicolor
# 1       virginica
# 51         setosa
# ...

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 141           6.9          3.1           5.1          2.3   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 11            4.8          3.4           1.6          0.2      setosa
# 127           6.1          3.0           4.9          1.8   virginica
# 97            6.2          2.9           4.3          1.3  versicolor
# ..            ...          ...           ...          ...         ...
# 88            5.6          3.0           4.1          1.3  versicolor
# 117           7.7          3.8           6.7          2.2   virginica
# 50            7.0          3.2           4.7          1.4  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 48            5.3          3.7           1.5          0.2      setosa
#
#         cluster
# 141  versicolor
# 105  versicolor
# 11    virginica
# 127   virginica
# 97       setosa
# ..          ...
# ...

# %%
import matplotlib
import pandas as pd

# %%
data = pd.DataFrame()
data['year'] = [2015, 2016, 1980, 1982, 1981]
data['unemployment'] = [6.0, 5.7, 7.1, 7.6, 9.7]
data['country'] = ['au', 'au', 'usa', 'usa', 'usa']

# %%
data = data.sort_values('year')
data.groupby('country').plot(x='year', y='unemployment', legend=False)
# Out:
# country
# au     AxesSubplot(0.125,0.125;0.775x0.755)
# usa    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
