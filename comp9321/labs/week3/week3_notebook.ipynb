# %%
import pandas as pd
import numpy as np


def print_data_frame(data_frame, print_columns=True, print_rows=True):
    if print_columns:
        print(",".join([column for column in data_frame]))
    if print_rows:
        for index, row in data_frame.iterrows():
            print(",".join([str(row[column]) for column in data_frame]))

drop_list = ['Edition Statement',
                 'Corporate Author',
                 'Corporate Contributors',
                 'Former owner',
                 'Engraver',
                 'Contributors',
                 'Issuance type',
                 'Shelfmarks']
csv_file = 'Books.csv'
data_frame = pd.read_csv(csv_file)
columns = [column for column in data_frame]
print(data_frame.isna().sum())
# Out:
# Identifier                 0
# Edition Statement         17
# Place of Publication       0
# Date of Publication        1
# Publisher                 10
# Title                      0
# Author                     2
# Contributors               0
# Corporate Author          20
# Corporate Contributors    20
# Former owner              20
# Engraver                  20
# Issuance type              0
# Flickr URL                 0
# Shelfmarks                 0
# dtype: int64

# %%
data_frame.shape
# Out:
# (20, 15)

# %%
data_frame[drop_list[5]].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Contributors, dtype: bool

# %%
data_frame[drop_list[5]].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Contributors, dtype: bool

# %%
type(data_frame.columns)
print(",".join(data_frame.columns))
print(",".join([column for column in data_frame]))
# Out:
# Identifier,Edition Statement,Place of Publication,Date of Publication,Publisher,Title,Author,Contributors,Corporate Author,Corporate Contributors,Former owner,Engraver,Issuance type,Flickr URL,Shelfmarks
# Identifier,Edition Statement,Place of Publication,Date of Publication,Publisher,Title,Author,Contributors,Corporate Author,Corporate Contributors,Former owner,Engraver,Issuance type,Flickr URL,Shelfmarks

# %%
data_frame.shape
# Out:
# (20, 15)

# %%
data_frame.drop(drop_list, inplace=False, axis=1)
# Out:
#     Identifier      Place of Publication Date of Publication  \
# 0          206                    London         1879 [1878]
# 1          216  London; Virtue & Yorston                1868
# 2          218                    London                1869
# 3          472                    London                1851
# 4          480                    London                1857
# 5          481                    London                1875
# 6          519                    London                1872
# 7          667               Puerto Rico                 NaN
# 8          874                   London]                1676
# 9         1143                    London                1676
# 10        1280                  Coventry                1802
# 11        1808               Christiania                1859
# 12        1905                   Firenze                1888
# 13        1929                 Amsterdam         1676, 38-54
# ...

# %%
data_frame.shape
# Out:
# (20, 15)

# %%
pd.Series([1,2], index=['A', 'B'], )
# Out:
# A    1
# B    2
# dtype: int64

# %%
pd.Series([1,2], )
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
pd.DataFrame(np.array(range(10)).reshape(2,5))
# Out:
#    0  1  2  3  4
# 0  0  1  2  3  4
# 1  5  6  7  8  9

# %%
feature = "Place of Publication"
temp = data_frame[feature]
print(temp)
f = lambda x: 'London' if 'London' in x else x.replace('-', ' ')
temp.apply(f, axis=1)
# Out:
# 0                       London
# 1     London; Virtue & Yorston
# 2                       London
# 3                       London
# 4                       London
# 5                       London
# 6                       London
# 7                  Puerto Rico
# 8                      London]
# 9                       London
# 10                    Coventry
# 11                 Christiania
# 12                     Firenze
# 13                   Amsterdam
# 14                      Savona
# 15                      London
# 16                       Paris
# 17                       Paris
# 18                 Puerto-Rico
# 19                    New York
# Name: Place of Publication, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-47e1965c3b1e> in <module>
#       3 print(temp)
# ...

# %%
df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

# %%
data_frame[feature]
# Out:
# 0                       London
# 1     London; Virtue & Yorston
# 2                       London
# 3                       London
# 4                       London
# 5                       London
# 6                       London
# 7                  Puerto Rico
# 8                      London]
# 9                       London
# 10                    Coventry
# 11                 Christiania
# 12                     Firenze
# 13                   Amsterdam
# 14                      Savona
# 15                      London
# 16                       Paris
# 17                       Paris
# 18                 Puerto-Rico
# 19                    New York
# Name: Place of Publication, dtype: object

# %%
data_frame.apply(lambda x: [1,2], axis=0)
# Out:
# Identifier                [1, 2]
# Edition Statement         [1, 2]
# Place of Publication      [1, 2]
# Date of Publication       [1, 2]
# Publisher                 [1, 2]
# Title                     [1, 2]
# Author                    [1, 2]
# Contributors              [1, 2]
# Corporate Author          [1, 2]
# Corporate Contributors    [1, 2]
# Former owner              [1, 2]
# Engraver                  [1, 2]
# Issuance type             [1, 2]
# Flickr URL                [1, 2]
# Shelfmarks                [1, 2]
# dtype: object

# %%
df.apply(lambda x: [1, 2, 5, 7], axis=1)
# Out:
# 0    [1, 2, 5, 7]
# 1    [1, 2, 5, 7]
# 2    [1, 2, 5, 7]
# dtype: object

# %%
df.apply(lambda x: [1, 2, 5, 7], axis=0)
# Out:
# A    [1, 2, 5, 7]
# B    [1, 2, 5, 7]
# dtype: object

# %%
g('a')
# Out:
# [1, 2]

# %%
feature = "Date of Publication"
new_date = data_frame[feature].str.extract(r'^(\d{4})', expand=False)
print(new_date)
new_date = pd.to_numeric(new_date)
print(new_date)
# Out:
# 0     1879
# 1     1868
# 2     1869
# 3     1851
# 4     1857
# 5     1875
# 6     1872
# 7      NaN
# 8     1676
# 9     1676
# 10    1802
# 11    1859
# 12    1888
# 13    1676
# 14    1888
# 15    1888
# 16    1860
# 17    1873
# 18    1866
# 19    1899
# Name: Date of Publication, dtype: object
# 0     1879.0
# 1     1868.0
# 2     1869.0
# 3     1851.0
# 4     1857.0
# 5     1875.0
# 6     1872.0
# 7        NaN
# 8     1676.0
# 9     1676.0
# 10    1802.0
# 11    1859.0
# 12    1888.0
# 13    1676.0
# 14    1888.0
# 15    1888.0
# 16    1860.0
# 17    1873.0
# 18    1866.0
# 19    1899.0
# Name: Date of Publication, dtype: float64

# %%
data_frame.Identifier
# Out:
# 0      206
# 1      216
# 2      218
# 3      472
# 4      480
# 5      481
# 6      519
# 7      667
# 8      874
# 9     1143
# 10    1280
# 11    1808
# 12    1905
# 13    1929
# 14    2836
# 15    2854
# 16    2956
# 17    2957
# 18    3017
# 19    3131
# Name: Identifier, dtype: int64

# %%
ct_df = pd.read_csv('City.csv')
ct_df
# Out:
#           City      Country
# 0       London      England
# 1  Puerto Rico        U.S.A
# 2     Coventry      England
# 3  Christiania      Denmark
# 4      Firenze        Italy
# 5    Amsterdam  Netherlands
# 6       Savona        Italy
# 7        Paris       France
# 8     New York        U.S.A

# %%
data_frame
# Out:
#     Identifier                                  Edition Statement  \
# 0          206                                                NaN
# 1          216                                                NaN
# 2          218                                                NaN
# 3          472                                                NaN
# 4          480                       A new edition, revised, etc.
# 5          481                      Fourth edition, revised, etc.
# 6          519                                                NaN
# 7          667                                                NaN
# 8          874                                                NaN
# 9         1143                                                NaN
# 10        1280                                                NaN
# 11        1808                                                NaN
# 12        1905                                                NaN
# ...

# %%
df = pd.merge(data_frame, ct_df, how='left', left_on=['Place of Publication'], right_on=['City'])

# %%
df
# Out:
#     Identifier                                  Edition Statement  \
# 0          206                                                NaN
# 1          216                                                NaN
# 2          218                                                NaN
# 3          472                                                NaN
# 4          480                       A new edition, revised, etc.
# 5          481                      Fourth edition, revised, etc.
# 6          519                                                NaN
# 7          667                                                NaN
# 8          874                                                NaN
# 9         1143                                                NaN
# 10        1280                                                NaN
# 11        1808                                                NaN
# 12        1905                                                NaN
# ...

# %%
df
# Out:
#     Identifier                                  Edition Statement  \
# 0          206                                                NaN
# 1          216                                                NaN
# 2          218                                                NaN
# 3          472                                                NaN
# 4          480                       A new edition, revised, etc.
# 5          481                      Fourth edition, revised, etc.
# 6          519                                                NaN
# 7          667                                                NaN
# 8          874                                                NaN
# 9         1143                                                NaN
# 10        1280                                                NaN
# 11        1808                                                NaN
# 12        1905                                                NaN
# ...

# %%
gb_df = df.groupby('Country', as_index=False)
gb_df

# %%
res1 = gb_df['Author'].count()
res1
# Out:
#        Country  Author
# 0      Denmark       1
# 1      England       8
# 2       France       2
# 3        Italy       2
# 4  Netherlands       0
# 5        U.S.A       2

# %%
res2 = gb_df['Identifier'].count()
res2
# Out:
#        Country  Identifier
# 0      Denmark           1
# 1      England           9
# 2       France           2
# 3        Italy           2
# 4  Netherlands           1
# 5        U.S.A           2
